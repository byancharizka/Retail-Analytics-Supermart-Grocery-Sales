# %% [markdown]
# # **RETAIL ANALYTICS**
#
# Proses penyediaan data analitis tentang tingkat inventaris, pergerakan rantai pasokan, permintaan konsumen, penjualan, dan lain-lain yang merupakan hal yang penting dakam membuat keputusan pemasaran dan pengadaan.
#
# Analisis data permintaan dan pasokan dapat digunakan untuk mempertahankan tingkat pengadaan dan juga untuk mengambil keputusan pemasaran. Analisis ritel memberi kita wawasan pelanggan yang terperinci serta wawasan tentang bisnis dan proses organisasi dengan cakupan dan kebutuhan untuk perbaikan.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/My Drive/retail-analytics/data/retail-data.csv",index_col=0)
df
# Out:
#          Customer Name           Category      Sub Category         City  \
# Order ID
# OD1             Harish       Oil & Masala           Masalas      Vellore
# OD2              Sudha          Beverages     Health Drinks  Krishnagiri
# OD3            Hussain        Food Grains      Atta & Flour   Perambalur
# OD4            Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# OD5            Ridhesh        Food Grains   Organic Staples         Ooty
# ...                ...                ...               ...          ...
# OD9990          Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# OD9991            Alan             Bakery          Biscuits  Kanyakumari
# OD9992            Ravi        Food Grains              Rice         Bodi
# OD9993            Peer       Oil & Masala            Spices   Pudukottai
# OD9994          Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
#           Order Date Region  Sales  Discount  Profit       State
# Order ID
# ...

# %%
# Cek unique data dari kolom State
df.State.unique()
# Out:
# array(['Tamil Nadu'], dtype=object)

# %%
# Hapus kolom State karna hanya ada 1 unique data
df.drop("State", axis=1, inplace=True)

# %%
df
# Out:
#          Customer Name           Category      Sub Category         City  \
# Order ID
# OD1             Harish       Oil & Masala           Masalas      Vellore
# OD2              Sudha          Beverages     Health Drinks  Krishnagiri
# OD3            Hussain        Food Grains      Atta & Flour   Perambalur
# OD4            Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# OD5            Ridhesh        Food Grains   Organic Staples         Ooty
# ...                ...                ...               ...          ...
# OD9990          Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# OD9991            Alan             Bakery          Biscuits  Kanyakumari
# OD9992            Ravi        Food Grains              Rice         Bodi
# OD9993            Peer       Oil & Masala            Spices   Pudukottai
# OD9994          Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
#           Order Date Region  Sales  Discount  Profit
# Order ID
# ...

# %%
df.columns
# Out:
# Index(['Customer Name', 'Category', 'Sub Category', 'City', 'Order Date',
#        'Region', 'Sales', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.City.nunique()
# Out:
# 24

# %%
df.City.unique()
# Out:
# array(['Vellore', 'Krishnagiri', 'Perambalur', 'Dharmapuri', 'Ooty',
#        'Trichy', 'Ramanadhapuram', 'Tirunelveli', 'Chennai', 'Karur',
#        'Namakkal', 'Dindigul', 'Kanyakumari', 'Bodi', 'Tenkasi',
#        'Viluppuram', 'Madurai', 'Salem', 'Cumbum', 'Nagercoil',
#        'Pudukottai', 'Theni', 'Coimbatore', 'Virudhunagar'], dtype=object)
